# %%
include("../src/Plinear.jl")
include("../src/Bispectrum.jl")
# Out:
# B411 (generic function with 1 method)

# %%
using Plots

# %%
PLL = PLint_from_file("../data/test_Pk.dat");

# %%
bias = Dict("b1" => 2, "b2" => 1, "b3" => 0.5, "gamma2" => 0.3, "gamma21" => 0.2, "gamma211" => 0.2, "gamma21x" => 0.2, "gamma22" => 0.2, "gamma2x" => 0.1, "gamma3" => 0.2, "gamma31" => 0.1);

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.2, 0.2, 0.2])
# Out:
# (-5.145801374193414e11, 1.1159707464583657e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.3, 0.3, 0.3])
# Out:
# (-9.06726342436012e11, 1.859198874539716e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.4, 0.4, 0.4])
# Out:
# (-1.1281184151055566e12, 2.289936726531289e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [1.4, 1.4, 1.4])
# Out:
# (1.0814568798077043e13, 1.905620006996657e13)

# %%
p = []
for i in -100:100
    push!(p, B222int(k1, k2, [0.1, 0.15, i*0.01], 0.7, bias, PLL)[1])
end
scatter(abs.(p), yaxis=:log)

# %%
p
# Out:
# 201-element Vector{Any}:
#  -11983.517089798137
#  -13215.909766312609
#  -14572.090534855579
#  -16040.21753933385
#  -17665.54130223902
#  -19412.3896436723
#  -21355.09104808387
#  -23437.328500682943
#  -25745.166806285677
#  -28230.864093031985
#       ⋮
#   99592.95615852466
#   94268.61369587031
#   89136.73981737033
#   84312.00947173714
#   79715.50033549199
#   75342.525841124
#   71240.89224242642
#   67298.35763852514
#   63644.746016509656

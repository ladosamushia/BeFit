# %%
include("../src/Plinear.jl")
include("../src/Bispectrum.jl")
# Out:
# B411 (generic function with 1 method)

# %%
using Plots
using Cuba

# %%
PLL = PLint_from_file("../data/test_Pk.dat");

# %%
bias = Dict("b1" => 2, "b2" => 1, "b3" => 0.5, "gamma2" => 0.3, "gamma21" => 0.2, "gamma211" => 0.2, "gamma21x" => 0.2, "gamma22" => 0.2, "gamma2x" => 0.1, "gamma3" => 0.2, "gamma31" => 0.1);

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.2, 0.2, 0.2])
# Out:
# (-1.0377262464449894e12, 1.4429454333312754e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.3, 0.3, 0.3])
# Out:
# (-1.2681051497432974e12, 2.3328462972670186e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
B222(k1, k2, 0.7, bias, PLL, [0.4, 0.4, 0.4])
# Out:
# (-1.7152310544269824e12, 3.135238503547845e12)

# %%
k1 = [0.1, 0.1, 0.1]
k2 = [0.11, 0.11, 0.11]
kmax = collect(0.1:0.1:2.0)
Bconv = zeros(length(kmax))
for i in 1:length(Bconv)
    Bconv[i] = B222sp(k1, k2, 0.7, bias, PLL, kmax[i])
end
plot(kmax, Bconv)

# %%
k1 = [0.01, 0.02, 0.03]
k2 = [0.03, -0.02, 0.02]
kmax = collect(0.1:0.1:2.0)
Bconv = zeros(length(kmax))
for i in 1:length(Bconv)
    Bconv[i] = B222sp(k1, k2, 0.7, bias, PLL, kmax[i])
end
plot(kmax, Bconv)
